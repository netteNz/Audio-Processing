# %%
#%# 
# %matplotlib inline
import matplotlib.pyplot as plt

from scipy.io import wavfile

samplerate, data = wavfile.read('mirrored.wav')

# %%
samplerate
# Out:
# 44100

# %%
data.shape
# Out:
# (8169984, 2)

# %%
data.shape[0]
# Out:
# 8169984

# %%
samples = data.shape[0]
samples
# Out:
# 8169984

# %%
plt.plot(data[:300])
# Out:
# [<matplotlib.lines.Line2D at 0xb947d0>, <matplotlib.lines.Line2D at 0xb94890>]

# %%
from scipy.fftpack import fft, fftfreq

# %%
freqs = fftfreq(samples,1/samplerate)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-34-8ae9503f34c3> in <module>
# ----> 1 freqs = fftfreq(samples,1/samplerate)
#
# c:\python37\lib\site-packages\numpy\fft\helper.py in fftfreq(n, d)
#     175     p2 = arange(-(n//2), 0, dtype=int)
#     176     results[N:] = p2
# --> 177     return results * val
#     178
#     179
#
# MemoryError:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from scipy.io import wavfile
from scipy.fftpack import fft, fftfreq

samplerate, data = wavfile.read('mirrored.wav')

print(samplerate)
print(data.shape)
data.shape[0]
samples = data.shape[0]
print(samples)

plt.plot(data[:300])
%#%
datafft = fft(data)
#Get the absolute value of real and complex component:
fftabs = abs(datafft)
freqs = fftfreq(samples, 1/samplerate)

from scipy.fftpack import fft, fftfreqplt.plot(freqs,fftabs)
# Out:
# 44100
# (8169984, 2)
# 8169984
# UsageError: Line magic function `%#%` not found.

# %%
from scipy.fftpack import fft, fftfreq

datafft = fft(data)
#Get the absolute value of real and complex component:
fftabs = abs(datafft)
freqs = fftfreq(samples, 1/samplerate)

plt.plot(freqs,fftabs)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-7-5ac7cad08c59> in <module>
#       1 from scipy.fftpack import fft, fftfreq
#       2
# ----> 3 datafft = fft(data)
#       4 #Get the absolute value of real and complex component:
#       5 fftabs = abs(datafft)
#
# c:\python37\lib\site-packages\scipy\fftpack\basic.py in fft(x, n, axis, overwrite_x)
#     282
#     283     if axis == -1 or axis == len(tmp.shape) - 1:
# --> 284         return work_function(tmp,n,1,0,overwrite_x)
#     285
#     286     tmp = swapaxes(tmp, axis, -1)
#
# MemoryError:
